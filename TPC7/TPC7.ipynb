# %% [markdown]
# ---
#
# ## TPC7: Teste de aferição
#
# Resolva os problemas apresentados a seguir.

# %% [markdown]
# ### tpc-1. Especifique as seguintes listas em compreensão:

# %% [markdown]
# #### a) Lista formada pelos elementos que não são comuns às duas listas:

# %%
lista1 = [1, 2, 3, 4, 5]
lista2 = [4, 5, 6, 7, 8]  
ncomuns = []
for i in lista1:
    if i not in lista2:
        ncomuns.append(i)
for i in lista2:
    if i not in lista1:
        ncomuns.append(i)
print(ncomuns)
# Resultado esperado: [1,2,3,6,7,8]
# Out:
# [1, 2, 3, 6, 7, 8]

# %% [markdown]
# #### b) Lista formada pelas palavras do texto compostas por mais de 3 letras:

# %%
texto = """Vivia há já não poucos anos algures num concelho do Ribatejo 
    um pequeno lavrador e negociante de gado chamado Manuel Peres Vigário"""
lista = []
palavras=texto.split()
for pal in palavras:
    if len(pal)>3:
        lista.append(pal)
print(lista)
# Resultado esperado: ['Vivia', 'poucos', 'anos', 'algures', 'concelho', ...]
# Out:
# ['Vivia', 'poucos', 'anos', 'algures', 'concelho', 'Ribatejo', 'pequeno', 'lavrador', 'negociante', 'gado', 'chamado', 'Manuel', 'Peres', 'Vigário']

# %% [markdown]
# #### c) Lista formada por pares do tipo (índice, valor) com os valores da lista dada:

# %%
lista = ['anaconda', 'burro', 'cavalo', 'macaco']
pos=1
listaRes = []
for elem in lista:
    listaRes.append((pos,elem))
    pos=pos+1
print(listaRes)
# Resultado esperado: [(1,'anaconda'), (2,'burro'), (3,'cavalo'), (4,'macaco')]
# Out:
# [(1, 'anaconda'), (2, 'burro'), (3, 'cavalo'), (4, 'macaco')]

# %% [markdown]
# ### tpc-2. À semelhança do que foi feito nas aulas, realize as seguintes tarefas:

# %% [markdown]
# #### a) Especifique uma função que dada uma string e uma substring não vazia, calcula  o número de vezes em que a substring aparece na string, sem que haja sobreposição de substrings:

# %%
def strCount(s, subs):
    contar=0
    i=0
    while i<=len(s)-len(subs):
        if s[i:i+(len(subs))]==subs:
            contar=contar+1
            i=i+len(subs)
        else:
            i=i+1
    return contar

print(strCount("catcowcat", "cat")) # --> 2
print(strCount("catcowcat", "cow")) # --> 1
print(strCount("catcowcat", "dog")) # --> 0
print(strCount("aaaaaa", "aa"))
# Out:
# 2
# 1
# 0
# 3

# %% [markdown]
# #### b) Especifique uma função que recebe uma lista de números inteiros positivos e devolve o menor produto que for possível calcular multiplicando os 3 menores inteiros da lista:

# %%
def produtoM3(lista):
    trocas=True
    while trocas==True:
        i=0
        trocas=False
        while i<len(lista)-1:
            if lista[i]>lista[i+1]:
                lista[i],lista[i+1]=lista[i+1],lista[i]
                trocas=True
            i=i+1
    return f"{lista[0]*lista[1]*lista[2]}={lista[0]}*{lista[1]}*{lista[2]}"
print(produtoM3([12,3,7,10,12,8,9]))
# Resultado esperado: 168 = 3 * 7 * 8
# Out:
# 168=3*7*8

# %% [markdown]
# #### c) Especifique uma função que dado um número inteiro positivo, repetidamente adiciona os seus dígitos até obter apenas um dígito que é retornado como resultado:

# %%
# Input: 38
# Output: 2
# Explicação: 3 + 8 = 11, 1 + 1 = 2.

# Input: 777
# Output: 3
# Explicação: 7 + 7 + 7 = 21, 2 + 1 = 3.

def reduxInt(n):
    while n>=10:
        soma=0
        for num in str(n):
            soma=soma+int(num)
        n=soma
    return n

print(reduxInt(55))
print(reduxInt(38))
print(reduxInt(777))
# Out:
# 1
# 2
# 3

# %% [markdown]
# #### d) Especifique uma função que recebe duas strings, `string1` e `string2`, e devolve o índice da primeira ocorrência de `string2` em `string1`, caso não ocorra nenhuma vez a função deverá retornar `-1`:

# %%
# Invocação: indexOf("Hoje está um belo dia de sol!", "belo")
# Resultado: 13

# Invocação: indexOf("Hoje está um belo dia de sol!", "chuva")
# Resultado: -1

def myIndexOf(s1, s2):
    res=-1
    i=0
    while i<=len(s1)-len(s2):
        if s1[i:i+(len(s2))]==s2:
            res=i
        i=i+1
    return res
print(myIndexOf("Hoje está um belo dia de sol!", "chuva"))
print(myIndexOf("Hoje está um belo dia de sol!", "belo"))
# Out:
# -1
# 13

# %% [markdown]
# ### tpc-3. A Rede Social
#
# Considere que a informação sobre uma rede social está armazenada numa lista de dicionários.
#
# Cada dicionário, correspondente a um _post_ e tem chaves `id`, `conteudo`, `autor`, `dataCriacao` e `comentarios`.
# Por sua vez, `comentarios` é uma lista de dicionários com chaves `comentario` e `autor`.
#
# Considere o seguinte exemplo:
#
# ```
#     MyFaceBook = [{
#         'id': 'p1',
#         'conteudo': 'A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor
#     tem de realizar...',
#         'autor': 'jcr',
#         'dataCriacao': '2023-07-20',
#         'comentarios': [
#             {
#                 'comentario': 'Completamente de acordo...',
#                 'autor': 'prh'
#             },
#             {
#                 'comentario': 'Mas há quem goste...',
#                 'autor': 'jj'
#             }
#         ]},
#         {
#             'id': 'p2',
#             ...
#         },
#         ...
#         ]
# ```

# %%
MyFaceBook = [{
        'id': 'p1', 
        'conteudo': 'A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor tem de realizar...', 
        'autor': 'bernardina', 
        'dataCriacao': '2023-07-20', 
        'comentarios': [{'comentario': 'Completamente de acordo...','autor': 'prh'},
                        {'comentario': 'Mas há quem goste...','autor': 'jj'}]},
            {'id': 'p2', 
        'conteudo': 'A tarefa de avaliação é talvez a mais difícil das tarefas que um professor tem de realizar...', 
        'autor': 'joel', 
        'dataCriacao': '2023-07-28', 
        'comentarios': [{'comentario': 'Completamente de desacordo...','autor': 'prh'},
                        {'comentario': 'Não deve haver quem goste...','autor': 'jj'}]},
            {'id': 'p3', 
        'conteudo': 'A tarefa de avaliação é um bom método de avaliar se os alunos estão a perceber a matéria...', 
        'autor': 'joel', 
        'dataCriacao': '2023-08-28', 
        'comentarios': [{'comentario': 'O problema é que a tarefa de avaliação não devia definir o valor do aluno...','autor': 'jota'},
                        {'comentario': 'Completamente de acordo com o jota...','autor': 'lucas'}]},
            {'id': 'p4', 
        'conteudo': 'As aulas teóricas passam a ser de presença obrigatória...', 
        'autor': 'maria', 
        'dataCriacao': '2023-10-12', 
        'comentarios': [{'comentario': 'Na minha altura não eram','autor': 'rui'},
                        {'comentario': 'Acho muito bem! Melhor fomra de os alunos acompanharem a matéria','autor': 'sara'}]}]

# %% [markdown]
# Defina as seguintes funções de manipulação e consulta da rede social:

# %% [markdown]
# #### a) `quantosPost`, que indica quantos posts estão registados:

# %%
def quantosPost(redeSocial):
    return len(redeSocial) 


print(quantosPost(MyFaceBook))
# Out:
# 4

# %% [markdown]
# #### b)  `postsAutor`, que devolve a lista de posts de um determinado autor:

# %%
def postsAutor(redeSocial, autor):
    lista=[]
    for elem in redeSocial:
        if elem['autor']==autor:
            lista.append(elem)
    return lista

print(postsAutor(MyFaceBook,"joel"))
# Out:
# [{'id': 'p2', 'conteudo': 'A tarefa de avaliação é talvez a mais difícil das tarefas que um professor tem de realizar...', 'autor': 'joel', 'dataCriacao': '2023-07-28', 'comentarios': [{'comentario': 'Completamente de desacordo...', 'autor': 'prh'}, {'comentario': 'Não deve haver quem goste...', 'autor': 'jj'}]}, {'id': 'p3', 'conteudo': 'A tarefa de avaliação é um bom método de avaliar se os alunos estão a perceber a matéria...', 'autor': 'joel', 'dataCriacao': '2023-08-28', 'comentarios': [{'comentario': 'O problema é que a tarefa de avaliação não devia definir o valor do aluno...', 'autor': 'jota'}, {'comentario': 'Completamente de acordo com o jota...', 'autor': 'lucas'}]}]

# %% [markdown]
# #### c) `autores`, que devolve a lista de autores de posts ordenada alfabeticamente:

# %%
def autores(redeSocial):
    listaautores=[]
    for elem in redeSocial:
        if elem['autor'] not in listaautores:
            listaautores.append(elem['autor'])
    
    return sorted(listaautores)
print(autores(MyFaceBook))
# Out:
# ['bernardina', 'joel', 'maria']

# %%
def autores(redeSocial):
    listaautores=[]
    for elem in redeSocial:
        if elem['autor'] not in listaautores:
            listaautores.append(elem['autor'])
    trocas=True
    while trocas:
        i=0
        trocas=False
        while i<len(listaautores)-1:  #o python sabe ordenar strings inteiras por ordem alfabetica
            if listaautores[i]>listaautores[i+1]:
                listaautores[i],listaautores[i+1]=listaautores[i+1],listaautores[i]
                trocas=True
            i=i+1
    return listaautores

print(autores(MyFaceBook))
# Out:
# ['bernardina', 'joel', 'maria']

# %% [markdown]
# #### d) `insPost`, que acrescenta um novo post à rede social a partir dos parâmetros recebidos e devolve a nova rede social.
#
# O campo `id` devrá ser calculado a partir dos já existentes, por exemplo, se a rede tiver posts com id `p1`, `p2` e `p3`, o novo `id` deverá ser `p4`.

# %%
def insPost(redeSocial, conteudo, autor, dataCriacao, comentarios):
    novo_post={
        "id":"p"+str(int(redeSocial[-1]['id'][1])+1),
        "conteudo":conteudo,
        "autor":autor,
        "dataCriação":dataCriacao,
        "comentarios":comentarios
    }
    redeSocial.append(novo_post)
    return redeSocial

MyFaceBook=insPost(MyFaceBook,'Os alunos não vão ser mais avalidados com fichas de avaliação...', "Rita", "2024-03-14", [{'comentario': 'Penso que isso levará os alunos a descartarem a resposabilidade de estudar e compreender a matéria...','autor': 'daniel'},
                        {'comentario': 'Não concordo! Deveriam sim haver provas de avaliação...','autor': 'joaquim'}])
print(MyFaceBook)
# Out:
# [{'id': 'p1', 'conteudo': 'A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor tem de realizar...', 'autor': 'bernardina', 'dataCriacao': '2023-07-20', 'comentarios': [{'comentario': 'Completamente de acordo...', 'autor': 'prh'}, {'comentario': 'Mas há quem goste...', 'autor': 'jj'}]}, {'id': 'p2', 'conteudo': 'A tarefa de avaliação é talvez a mais difícil das tarefas que um professor tem de realizar...', 'autor': 'joel', 'dataCriacao': '2023-07-28', 'comentarios': [{'comentario': 'Completamente de desacordo...', 'autor': 'prh'}, {'comentario': 'Não deve haver quem goste...', 'autor': 'jj'}]}, {'id': 'p3', 'conteudo': 'A tarefa de avaliação é um bom método de avaliar se os alunos estão a perceber a matéria...', 'autor': 'joel', 'dataCriacao': '2023-08-28', 'comentarios': [{'comentario': 'O problema é que a tarefa de avaliação não devia definir o valor do aluno...', 'autor': 'jota'}, {'comentario': 'Completamente de acordo com o jota...', 'autor': 'lucas'}]}, {'
# ...

# %% [markdown]
# #### e)  `remPost`, que remove um post da rede, correspondente ao `id` recebido.

# %%
def remPost(redeSocial, id):
    nlista=[]
    for elem in redeSocial:
        if elem['id']!=id:
            nlista.append(elem)
    if nlista==redeSocial:
        print("Não foi encontrado nenhum id igual ao que escolheu e por isso não removeu o post")
    return nlista

# %%
#Ou
def remPost(redeSocial, idPost):
    nlista = []
    encontrado = False
    for elem in redeSocial:
        if elem['id'] != idPost:
            nlista.append(elem)
        else:
            encontrado = True 
    if not encontrado:
        print("Não foi encontrado nenhum id igual ao que escolheu, por isso não removeu o post.")
    return nlista

MyFaceBook=remPost(MyFaceBook,"p5")
print(MyFaceBook)
# Out:
# [{'id': 'p1', 'conteudo': 'A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor tem de realizar...', 'autor': 'bernardina', 'dataCriacao': '2023-07-20', 'comentarios': [{'comentario': 'Completamente de acordo...', 'autor': 'prh'}, {'comentario': 'Mas há quem goste...', 'autor': 'jj'}]}, {'id': 'p2', 'conteudo': 'A tarefa de avaliação é talvez a mais difícil das tarefas que um professor tem de realizar...', 'autor': 'joel', 'dataCriacao': '2023-07-28', 'comentarios': [{'comentario': 'Completamente de desacordo...', 'autor': 'prh'}, {'comentario': 'Não deve haver quem goste...', 'autor': 'jj'}]}, {'id': 'p3', 'conteudo': 'A tarefa de avaliação é um bom método de avaliar se os alunos estão a perceber a matéria...', 'autor': 'joel', 'dataCriacao': '2023-08-28', 'comentarios': [{'comentario': 'O problema é que a tarefa de avaliação não devia definir o valor do aluno...', 'autor': 'jota'}, {'comentario': 'Completamente de acordo com o jota...', 'autor': 'lucas'}]}, {'
# ...

# %% [markdown]
# #### f) `postsPorAutor`, que devolve uma distribuição de posts por autor (à semelhança do que foi feito nas aulas).

# %%
def postsPorAutor(redeSocial):
    distrib={}
    for elem in redeSocial:
        if elem['autor'] in distrib:
            distrib[elem["autor"]]=distrib[elem["autor"]]+1
        else:
            distrib[elem["autor"]]=1

    return distrib
print(postsPorAutor(MyFaceBook))
# Out:
# {'bernardina': 1, 'joel': 2, 'maria': 1}

# %% [markdown]
# #### g) `comentadoPor`, que recebe um autor e devolve a lista de posts comentados por esse autor.

# %%
def comentadoPor(redeSocial, autor):
    comment=[]
    encontrado=False
    for elem in redeSocial:
        for coment in elem['comentarios']:
            if coment['autor']==autor:
                comment.append(elem)
                encontrado=True
    if encontrado==False:
        print("Não foi encontrado!")
    return comment

print(comentadoPor(MyFaceBook,"lucas"))
# Out:
# [{'id': 'p3', 'conteudo': 'A tarefa de avaliação é um bom método de avaliar se os alunos estão a perceber a matéria...', 'autor': 'joel', 'dataCriacao': '2023-08-28', 'comentarios': [{'comentario': 'O problema é que a tarefa de avaliação não devia definir o valor do aluno...', 'autor': 'jota'}, {'comentario': 'Completamente de acordo com o jota...', 'autor': 'lucas'}]}]
